# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

import numpy as np

# %%
df = pd.read_csv('cycle.csv')

# %%
df['load'].plot()
plt.show()

# %%
df[70:]['load'].plot()
plt.hlines(99166, 70, 400, color='red')

plt.vlines(83, 99100, 99200, color='red')
plt.vlines(154, 99100, 99200, color='red')
plt.vlines(226, 99100, 99200, color='red')
plt.vlines(298, 99100, 99200, color='red')
plt.vlines(370, 99100, 99200, color='red')
plt.show()

# %%
for i, row in df.iterrows():
    if row['load'] == 99166:
        print(row)
# Out:
# cycle       83
# load     99166
# Name: 82, dtype: int64
# cycle      155
# load     99166
# Name: 154, dtype: int64
# cycle      227
# load     99166
# Name: 226, dtype: int64
# cycle      299
# load     99166
# Name: 298, dtype: int64
# cycle      371
# load     99166
# Name: 370, dtype: int64

# %%
df['load'][82:154].values
# Out:
# array([99166, 99165, 99137, 99137, 99111, 99099, 99118, 99131, 99162,
#        99150, 99139, 99142, 99146, 99095, 99112, 99133, 99147, 99146,
#        99124, 99144, 99151, 99130, 99108, 99127, 99149, 99131, 99120,
#        99129, 99153, 99135, 99143, 99123, 99143, 99133, 99105, 99125,
#        99138, 99137, 99148, 99158, 99139, 99127, 99107, 99110, 99134,
#        99122, 99150, 99163, 99174, 99123, 99101, 99112, 99119, 99118,
#        99135, 99165, 99179, 99158, 99097, 99106, 99121, 99103, 99131,
#        99150, 99181, 99163, 99132, 99102, 99115, 99105, 99116, 99146])
